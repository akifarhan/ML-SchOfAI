# %% [markdown]
# <a href="https://colab.research.google.com/github/akifarhan/ML-SchOfAI/blob/master/kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# np.random.seed(60)

# %%
df = pd.read_csv('https://huseinhouse.com/dataset/mall-customer.csv')
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
X = df['Annual Income (k$)'].values
Y = df['Spending Score (1-100)'].values
plt.scatter(X, Y)
plt.show()

# %%
k = 8
random_centroids = np.random.randint(0, X.shape[0], size = (6))
random_centroids
# Out:
# array([168,   9, 174, 102, 146, 194])

# %%
plt.scatter(X, Y)
plt.scatter(X[random_centroids], Y[random_centroids], label = 'centroid',
           c = 'red', marker = 'X', s = 100)
plt.show()

# %% [markdown]
# ## I want to use euclidean distance as distance function
#
# ```
# d(x, y) = sqrt(sum((x - y)^2))
# ```

# %%
X = df.iloc[:,-2:].values

# %%
pp_centroids = [X[random_centroids[0]]]

for i in range(1, k, 1):
  D = np.array([np.sqrt(np.sum((x - pp_centroids)** 2)) for x in X])
  prob = D / D.sum()
  cumsum = prob.cumsum()
  r = np.random.random()
  where = np.where(cumsum > r)[0]
  pp_centroids.append(X[where[0]])

# %%
pp_centroids = np.array(pp_centroids)

# %%
plt.scatter(X[:,0], X[:, 1])
plt.scatter(pp_centroids[:,0], pp_centroids[:,1], label = 'centroid',
           c = 'red', marker = 'X', s = 100)
plt.show()

# %%
pp_centroids_float = pp_centroids.astype('float')

# %%
D = np.array([np.sqrt(np.sum((X - c)** 2, axis = 1)) for \
                    c in pp_centroids_float])
D = D.T
C = np.argmin(D, axis = 1)
for i in range(k):
  mean = X[C == i]
  pp_centroids_float[i] = np.mean(mean,axis=0)

# %%
plt.scatter(X[:,0], X[:, 1])
plt.scatter(pp_centroids_float[:,0], pp_centroids_float[:,1], label = 'centroid',
           c = 'red', marker = 'X', s = 100)
plt.show()

# %%
for _ in range(100):
  D = np.array([np.sqrt(np.sum((X - c)** 2, axis = 1)) for \
                    c in pp_centroids_float])
  D = D.T
  C = np.argmin(D, axis = 1)
  for i in range(k):
    mean = X[C == i]
    pp_centroids_float[i] = np.mean(mean,axis=0) + 1e-4

# %%
plt.scatter(X[:,0], X[:, 1])
plt.scatter(pp_centroids_float[:,0], pp_centroids_float[:,1], label = 'centroid',
           c = 'red', marker = 'X', s = 100)
plt.show()
